# %% [markdown]
# # Week 3 Quiz
#
# ## Qingci Luo - ql2466

# %% [markdown]
# ### Instructions
#
# Replace the Name and UNI in cell above and the notebook name
#
# Replace all '____' below using the instructions provided.
#
# When completed,
#  - make sure you've replaced Name and UNI in the first cell and filename  (eg: week_03_quiz-hw2592)
#  - Click the github link shared on canvas for quiz3 to generate your own repository of quiz3
#  - Click your own repository of quiz3 to commit your answers to github

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('darkgrid')

# %matplotlib inline

# %%
# Use pandas to read in 'wine_dataset.csv'
# This is a dataset of various wines with a target of categorical variable 'class'
from google.colab import drive
drive.mount('/content/drive') 
df = pd.read_csv('./drive/MyDrive/wine_dataset.csv')
df
# Out:
# Mounted at /content/drive
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36  2.67               18.6      101.0           2.80
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37               20.0      120.0           1.65
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
#      flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0          3.06                  0.28             2.29             5.64  1.04
# 1          2.76                  0.26             1.28             4.38  1.05
# 2          3.24                  0.30             2.81             5.68  1.03
# 3          3.49                  0.24             2.18             7.80  0.86
# 4          2.69                  0.39             1.82             4.32  1.04
# ..          ...                   ...              ...              ...   ...
# 173        0.61                  0.52             1.06             7.70  0.64
# 174        0.75                  0.43             1.41             7.30  0.70
# 175        0.69                  0.43             1.35            10.20  0.59
# 176        0.68                  0.53             1.46             9.30  0.60
# 177        0.76                  0.56             1.35             9.20  0.61
#
#      od280/od315_of_diluted_wines  proline  class
# 0                            3.92   1065.0      0
# 1                            3.40   1050.0      0
# 2                            3.17   1185.0      0
# 3                            3.45   1480.0      0
# 4                            2.93    735.0      0
# ..                            ...      ...    ...
# 173                          1.74    740.0      2
# 174                          1.56    750.0      2
# 175                          1.56    835.0      2
# 176                          1.62    840.0      2
# 177                          1.60    560.0      2
#
# [178 rows x 14 columns]

# %%
# 1. Print out the number of rows and columns in the dataset using shape
print(f'the number of rows and cols are {df.shape}')
# Out:
# the number of rows and cols are (178, 14)

# %%
# 2. Display the first 3 rows of df using head
df.head(3)
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
#
#    od280/od315_of_diluted_wines  proline  class
# 0                          3.92   1065.0      0
# 1                          3.40   1050.0      0
# 2                          3.17   1185.0      0

# %%
# 3. Display the summary stats of numeric columns using df.describe()
df.describe()
# Out:
#           alcohol  malic_acid         ash  alcalinity_of_ash   magnesium  \
# count  178.000000  178.000000  178.000000         178.000000  178.000000
# mean    13.000618    2.336348    2.366517          19.494944   99.741573
# std      0.811827    1.117146    0.274344           3.339564   14.282484
# min     11.030000    0.740000    1.360000          10.600000   70.000000
# 25%     12.362500    1.602500    2.210000          17.200000   88.000000
# 50%     13.050000    1.865000    2.360000          19.500000   98.000000
# 75%     13.677500    3.082500    2.557500          21.500000  107.000000
# max     14.830000    5.800000    3.230000          30.000000  162.000000
#
#        total_phenols  flavanoids  nonflavanoid_phenols  proanthocyanins  \
# count     178.000000  178.000000            178.000000       178.000000
# mean        2.295112    2.029270              0.361854         1.590899
# std         0.625851    0.998859              0.124453         0.572359
# min         0.980000    0.340000              0.130000         0.410000
# 25%         1.742500    1.205000              0.270000         1.250000
# 50%         2.355000    2.135000              0.340000         1.555000
# 75%         2.800000    2.875000              0.437500         1.950000
# max         3.880000    5.080000              0.660000         3.580000
#
#        color_intensity         hue  od280/od315_of_diluted_wines      proline  \
# count       178.000000  178.000000                    178.000000   178.000000
# mean          5.058090    0.957449                      2.611685   746.893258
# std           2.318286    0.228572                      0.709990   314.907474
# min           1.280000    0.480000                      1.270000   278.000000
# 25%           3.220000    0.782500                      1.937500   500.500000
# 50%           4.690000    0.965000                      2.780000   673.500000
# 75%           6.200000    1.120000                      3.170000   985.000000
# max          13.000000    1.710000                      4.000000  1680.000000
#
#             class
# count  178.000000
# mean     0.938202
# std      0.775035
# min      0.000000
# 25%      0.000000
# 50%      1.000000
# 75%      2.000000
# max      2.000000

# %%
# 4. Using iloc, display the first 3 rows, first 3 columns
# You should see the columns ['alcohol','malic_acid','ash']
df.iloc[:3,:3]
# Out:
#    alcohol  malic_acid   ash
# 0    14.23        1.71  2.43
# 1    13.20        1.78  2.14
# 2    13.16        2.36  2.67

# %%
# 5. Using loc, display rows with index 4 to 6 inclusive and columns 'ash' and 'total_phenols'
df.loc[4:6,['ash', 'total_phenols']]
# Out:
#     ash  total_phenols
# 4  2.87           2.80
# 5  2.45           3.27
# 6  2.45           2.50

# %%
# 6. Display 'ash' and 'hue' columns for all rows with 'hue' greater than the median value of hue
# This should result in 89 rows x 2 columns
from statistics import median
df[df['hue']>median(df['hue'])][['ash','hue']]
# Out:
#       ash   hue
# 0    2.43  1.04
# 1    2.14  1.05
# 2    2.67  1.03
# 4    2.87  1.04
# 5    2.45  1.05
# ..    ...   ...
# 112  2.92  1.23
# 113  2.50  1.10
# 115  2.20  1.71
# 117  2.19  1.06
# 127  2.78  0.97
#
# [89 rows x 2 columns]

# %%
# 7.1 Create a scatterplot of 'ash' and 'hue' for all rows in df using df.plot.scatter()
# Place ash on the x-axis and hue on the y-axis.
# Store the returned output in ax.
ax=df.plot.scatter(x='ash',y='hue')


# 7.2 Add the title 'Wine Ash vs Hue' to the plot using ax.set_title()
ax.set_title('Wine Ash vs Hue')
# Out:
# Text(0.5, 1.0, 'Wine Ash vs Hue')

# %%
# 8.1. Create two axes using plt.subplots with 1 row , 2 columns, and figsize=(10,4)
import matplotlib.pyplot as plt
import seaborn as sns
fig,ax = plt.subplots(1,2,figsize=(10,4))

# 8.2 In the first axis (ax[0]), plot the distribution of df.alcohol using sns.histplot()
#df.alcohol.plot.hist(bins=100, ax=ax[0])
plot1=sns.histplot(x='alcohol',data=df,ax=ax[0])

# 8.3 Add the title 'Wine Alcohol Content' to ax[0] using set_title()
plot1.set_title('Wine Alcohol Content')

# 8.4 In the second axis (ax[1]), plot a boxplot of df.color_intensity using sns.boxplot()
plot2=sns.boxplot(x='color_intensity',data=df,ax=ax[1])

# 8.5 Add the title 'Wine Color Intensity' to ax[1] using set_title()
plot2.set_title('Wine Color Intensity')
# Out:
# Text(0.5, 1.0, 'Wine Color Intensity')

# %%
# when completed, 
#   make sure you've replaced Name and UNI in the first cell and filename
#   and submit to GitHub classroom
